# %%
import numpy as np
import IPython.display as ipd
import glob
import librosa
import matplotlib.pyplot as plt

# %%
path = "../datasets/fa_audios/academia/academia_F01_001.wav"
audio, sr = librosa.load(path, sr=16000)

# %%
speaker_test = [""]
# Out:
# (array([-0.00286865, -0.00628662, -0.00534058, ..., -0.00332642,
#         -0.00357056, -0.00317383], dtype=float32),
#  16000)

# %%
data = glob.glob("/Documents/Doutorado/datasets/fernanda_audios/*.wav")
len(data)
# Out:
# 0

# %%
#audio = librosa.load(data[1], sr=44100)[0]
ipd.display(ipd.Audio(audio, rate=16000))
plt.plot(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio = librosa.load(data[1], sr=16000)[0]
ipd.display(ipd.Audio(audio, rate=16000))
plt.plot(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
